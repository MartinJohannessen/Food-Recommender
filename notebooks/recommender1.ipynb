# %%
import pandas as pd
import numpy as np

# %%
BMJ_data_all__b_new = pd.read_csv('../input/BMJ-data-all--b-new.csv', sep='\t')
item_profiles1 = pd.read_csv('../input/item-profiles1.csv', sep=';')
item_profiles2 = pd.read_csv('../input/item-profiles2.csv', sep=';')
item_profiles3 = pd.read_csv('../input/item-profiles3.csv', sep=';')
ratings = pd.read_csv('../input/user-item-rating.csv', sep='\t', names=['user_id','item_id','rating'])

# %%
type(ratings)
# Out:
# pandas.core.frame.DataFrame

# %%
item_profiles1.head
# Out:
# <bound method NDFrame.head of       Recipe ID                                           Category  \
# 0          1939          Home  >  Recipes  >  Main Dish  >  Roasts
# 1           771  Home  >  Recipes  >  Main Dish  >  Stuffed Mai...
# 2          3783  Home  >  Recipes  >  Main Dish  >  Steaks and ...
# 3           205  Home  >  Recipes  >  Main Dish  >  Burgers  > ...
# 4          1136  Home  >  Recipes  >  Meat and Poultry  >  Chic...
# ...         ...                                                ...
# 1026        863           Home  >  Recipes  >  Main Dish  >  Pasta
# 1027        168          Home  >  Recipes  >  Main Dish  >  Roasts
# 1028       1847  Home  >  Recipes  >  Main Dish  >  Steaks and ...
# 1029         67           Home  >  Recipes  >  Main Dish  >  Pasta
# 1030        462  Home  >  Recipes  >  Main Dish  >  Seafood  > ...
#
#                                              Directions
# 0     In a medium bowl, stir together the cranberry ...
# 1     On large plate, combine 1 tablespoon flour, sa...
# 2     In a blender, combine the soy sauce, honey, vi...
# 3     Preheat grill for high heat.<br>In a large bow...
# 4     Season both sides of chicken breasts with garl...
# ...                                                 ...
# 1026  In a large saute pan, heat oil, butter and gar...
# 1027  Cut up potatoes, onions, and celery in to fair...
# 1028  Preheat grill for high heat.<br>Use a fork to ...
# 1029  Bring a large pot of lightly salted water to a...
# 1030  Preheat oven to 400 degrees F (200 degrees C)....
#
# [1031 rows x 3 columns]>

# %%
item_profiles2.head
# Out:
# <bound method NDFrame.head of       Recipe ID                                      Name  Fiber (g)  \
# 0          2622  Slow Cooker Tender and Yummy Round Steak        4.5
# 1           722                        Chicken Pot Pie II        6.2
# 2          1137                          Chicken in a Pot        1.0
# 3          2502                 Erin's Indonesian Chicken        6.4
# 4          2714                              Bubble Pizza        3.0
# ...         ...                                       ...        ...
# 1026       1353                          Beef and Biscuit        0.9
# 1027        987                       Creamy Pesto Shrimp        2.7
# 1028       2903                            Boiled Chicken        1.2
# 1029       2136           Mushroom Sauce Baked Pork Chops        2.5
# 1030       3938                  Three Cheese Baked Pasta        5.2
#
#       Sodium (g)  Carbohydrates (g)  Fat (g)  Protein (g)  Sugar (g)  \
# 0           0.83               33.1     13.6         33.8        5.0
# 1           1.06               47.8     29.5         51.4        6.4
# 2           0.40                6.9      6.6         28.7        1.8
# 3           0.32               58.1     18.6         35.4        7.8
# 4           1.96               45.4     36.4         28.5        8.7
# ...          ...                ...      ...          ...        ...
# 1026        0.63               15.5     18.9         18.4        3.7
# 1027        0.44               43.0     42.5         23.1        0.2
# 1028        0.06                4.5     11.1         16.3        1.9
# 1029        1.11               28.1     14.3         19.0        6.5
# 1030        0.88               42.3     22.2         22.7       12.7
#
#       Saturated Fat (g)  Size (g)  Servings  Calories (kCal)  Average Rating  \
# 0                   4.6   2599.35       6.0            393.0            4.32
# 1                  11.4   2137.86       4.0            666.0            4.66
# 2                   1.4    819.37       4.0            206.0            4.29
# 3                   3.8   1972.13       4.0            530.0            4.39
# 4                  13.4   2375.00       8.0            624.0            4.35
# ...                 ...       ...       ...              ...             ...
# 1026                8.6   1536.45      10.0            306.0            3.99
# 1027               24.3   1655.88       8.0            646.0            4.58
# 1028                3.0   1780.00       8.0            186.0            4.70
# 1029                6.1   2241.75       6.0            316.0            4.45
# 1030               11.1   3368.20      12.0            463.0            4.57
#
#       Average Sentiment  Number of Ratings  Number of Bookmarks  \
# 0                  1.79                 81                 2271
# 1                  2.02                116                 1200
# 2                  1.98                 83                 1779
# 3                  1.99                 80                  872
# 4                  1.96                117                 2204
# ...                 ...                ...                  ...
# 1026               1.52                 79                  811
# 1027               1.98                225                 3134
# 1028               1.20                 74                 1083
# 1029               1.86                121                 1188
# 1030               1.76                 82                 1917
#
#       Year of Publishing
# 0                   2000
# 1                   2000
# 2                   2001
# 3                   2005
# 4                   2001
# ...                  ...
# 1026                2001
# 1027                2000
# 1028                2001
# 1029                2001
# 1030                2000
#
# [1031 rows x 17 columns]>

# %%
item_profiles3.shape
# Out:
# (9356, 5)

# %%
BMJ_data_all__b_new.head
# Out:
# <bound method NDFrame.head of                                                      URL  \
# 0      http://allrecipes.com/recipe/frosted-apricot-c...
# 1      http://allrecipes.com/recipe/italian-nachos-re...
# 2      http://allrecipes.com/recipe/brown-rice-and-ch...
# 3      http://allrecipes.com/recipe/erics-baked-chick...
# 4      http://allrecipes.com/recipe/olive-oil-pound-c...
# ...                                                  ...
# 58258  http://allrecipes.com/recipe/nikols-garlic-bru...
# 58259  http://allrecipes.com/recipe/slow-cooker-chick...
# 58260  http://allrecipes.com/recipe/bean-and-honey-bu...
# 58261  http://allrecipes.com/recipe/dill-dressing/det...
# 58262  http://allrecipes.com/recipe/chicken-and-artic...
#
#                                                  Name  Fiber (g)  Sodium (g)  \
# 0                             Frosted Apricot Cookies        0.7        0.20
# 1                     Italian Nachos Restaurant-Style        2.2        1.13
# 2                    Brown Rice and Chicken Casserole        2.4        0.71
# 3                                Eric's Baked Chicken        1.3        1.26
# 4                                Olive Oil Pound Cake        0.6        0.30
# ...                                               ...        ...         ...
# 58258                       Nikol's Garlic Bruschetta        0.9        0.17
# 58259                        Slow Cooker Chicken Stew        3.0        0.92
# 58260                Bean and Honey Burrito Casserole        4.9        0.60
# 58261                                   Dill Dressing        0.1        0.13
# 58262  Chicken And Artichoke Penne With A White Sauce        6.0        0.85
#
#        Carbohydrates (g)  Fat (g)  Protein (g)  Sugar (g)  Saturated Fat (g)  \
# 0                   24.6     11.2          2.2       11.1                7.3
# 1                   22.5     31.7         19.3        1.9               11.1
# 2                   19.1     10.0         17.5        3.1                4.6
# 3                   14.5     58.3         29.9        5.2               12.3
# 4                   44.0      3.7          4.5       26.1                0.9
# ...                  ...      ...          ...        ...                ...
# 58258               13.2      5.5          3.6        1.8                0.6
# 58259               28.6      7.6         47.2        4.7                2.1
# 58260               63.2     12.5         21.4       15.2                4.8
# 58261                0.4      1.8          0.1        0.1                0.1
# 58262               70.5     22.7         30.6        8.1                5.4
#
#        Size (g)  Servings  Calories (kCal)  Average Rating  Average Sentiment  \
# 0        610.20      12.0            203.0            3.00               1.50
# 1       1305.70       8.0            453.0            4.73               2.00
# 2       3099.18      12.0            238.0            3.29               0.00
# 3       2324.84       8.0            720.0            4.00               1.20
# 4       1112.48      12.0            227.0             NaN                NaN
# ...         ...       ...              ...             ...                ...
# 58258    856.15      12.0            113.0            5.00               2.00
# 58259   2596.18       6.0            378.0            4.29               1.59
# 58260   2424.90       8.0            446.0            4.44               1.88
# 58261    343.85      32.0             17.0             NaN                NaN
# 58262   1526.30       4.0            598.0            3.63               0.88
#
#        Number of Ratings  Number of Bookmarks  Year of Publishing
# 0                      2                   14                2004
# 1                     11                  195                2008
# 2                      7                  203                2005
# 3                      5                   89                2004
# 4                      0                    4                2005
# ...                  ...                  ...                 ...
# 58258                  7                  351                2009
# 58259                 17                  490                2001
# 58260                 16                  769                2009
# 58261                  0                   59                2010
# 58262                  8                  176                2001
#
# [58263 rows x 17 columns]>

# %%
#Import the train_test_split function
from sklearn.model_selection import train_test_split

#Assign X as the original ratings dataframe and y as the user_id column of ratings.
X = ratings.copy()
y = ratings['user_id']

#Split into training and test datasets, stratified along user_id
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, stratify=y, random_state=42)

# %%
#Import the mean_squared_error function
from sklearn.metrics import mean_squared_error

#Function that computes the root mean squared error (or RMSE)
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
#Function to compute the RMSE score obtained on the testing set by a model
def score(cf_model):
    
    #Construct a list of user-movie tuples from the testing dataset
    id_pairs = zip(X_test['user_id'], X_test['item_id'])
    
    #Predict the rating for every user-movie tuple
    y_pred = np.array([cf_model(user, item) for (user, item) in id_pairs])
    
    #Extract the actual ratings given by the users in the test data
    y_true = np.array(X_test['rating'])
    
    #Return the final RMSE score
    return rmse(y_true, y_pred)

# %%
#Define the baseline model to always return 3.
def baseline(user_id, item_id):
    return 3.0

# %%
score(baseline)
# Out:
# 1.6191040450231147

# %%
#Build the ratings matrix using pivot_table function
r_matrix = X_train.pivot_table(values='rating', index='user_id', columns='item_id')

r_matrix.head()
# Out:
# item_id  4      5      17     19     22     23     28     30     31     34     \
# user_id
# 455        NaN    NaN    NaN    NaN    NaN    NaN    5.0    NaN    NaN    5.0
# 559        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 833        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1155       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1299       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# item_id  ...  9098   9319   9661   9757   11194  11572  11895  13339  14078  \
# user_id  ...
# 455      ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 559      ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 833      ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1155     ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1299     ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# item_id  15746
# user_id
# 455        NaN
# 559        NaN
# 833        NaN
# 1155       NaN
# 1299       NaN
#
# [5 rows x 1031 columns]

# %%
#User Based Collaborative Filter using Mean Ratings
def cf_user_mean(user_id, item_id):
    
    #Check if item_id exists in r_matrix
    if item_id in r_matrix:
        #Compute the mean of all the ratings given to the movie
        mean_rating = r_matrix[item_id].mean()
    
    else:
        #Default to a rating of 3.0 in the absence of any information
        mean_rating = 3.0
    
    return mean_rating

# %%
#Compute RMSE for the Mean model
score(cf_user_mean)
# Out:
# 0.8063760052885885

# %%
#Create a dummy ratings matrix with all null values imputed to 0
r_matrix_dummy = r_matrix.copy().fillna(0)

# %%
# Import cosine_score 
from sklearn.metrics.pairwise import cosine_similarity

#Compute the cosine similarity matrix using the dummy ratings matrix
cosine_sim = cosine_similarity(r_matrix_dummy, r_matrix_dummy)

# %%
#Convert into pandas dataframe 
cosine_sim = pd.DataFrame(cosine_sim, index=r_matrix.index, columns=r_matrix.index)

cosine_sim.head(10)
# Out:
# user_id     455       559       833       1155      1299      1381      1537   \
# user_id
# 455      1.000000  0.008569  0.066906  0.000000  0.238620  0.031098  0.106433
# 559      0.008569  1.000000  0.015303  0.000000  0.016893  0.000000  0.000000
# 833      0.066906  0.015303  1.000000  0.138600  0.165588  0.000000  0.030412
# 1155     0.000000  0.000000  0.138600  1.000000  0.058287  0.057825  0.054596
# 1299     0.238620  0.016893  0.165588  0.058287  1.000000  0.029428  0.050359
# 1381     0.031098  0.000000  0.000000  0.057825  0.029428  1.000000  0.045940
# 1537     0.106433  0.000000  0.030412  0.054596  0.050359  0.045940  1.000000
# 1646     0.000000  0.000000  0.094756  0.000000  0.000000  0.000000  0.000000
# 1873     0.000000  0.000000  0.094720  0.038646  0.000000  0.054198  0.000000
# 2020     0.085897  0.000000  0.185697  0.000000  0.089128  0.036588  0.000000
#
# user_id     1646      1873      2020   ...     84374     84543     84570  \
# user_id                                ...
# 455      0.000000  0.000000  0.085897  ...  0.000000  0.035244  0.054074
# 559      0.000000  0.000000  0.000000  ...  0.000000  0.052397  0.080390
# 833      0.094756  0.094720  0.185697  ...  0.067479  0.115814  0.030902
# 1155     0.000000  0.038646  0.000000  ...  0.000000  0.056045  0.000000
# 1299     0.000000  0.000000  0.089128  ...  0.026486  0.000000  0.000000
# 1381     0.000000  0.054198  0.036588  ...  0.045304  0.030426  0.035010
# 1537     0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 1646     1.000000  0.000000  0.051222  ...  0.000000  0.049915  0.076582
# 1873     0.000000  1.000000  0.000000  ...  0.000000  0.000000  0.045236
# 2020     0.051222  0.000000  1.000000  ...  0.052689  0.044232  0.000000
#
# user_id     84572     84583     84767     84778     84780     84790     84839
# user_id
# 455      0.098218  0.049604  0.000000  0.130223  0.099014  0.032229  0.021552
# 559      0.099148  0.000000  0.000000  0.000000  0.000000  0.047914  0.021360
# 833      0.099613  0.120478  0.023367  0.000000  0.075344  0.115115  0.145744
# 1155     0.000000  0.000000  0.125845  0.051384  0.041405  0.024799  0.149245
# 1299     0.047811  0.000000  0.068787  0.000000  0.000000  0.071163  0.036257
# 1381     0.019627  0.000000  0.000000  0.032428  0.000000  0.062601  0.000000
# 1537     0.000000  0.058624  0.080539  0.121345  0.000000  0.087606  0.033961
# 1646     0.000000  0.070252  0.000000  0.000000  0.012194  0.000000  0.000000
# 1873     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2020     0.047556  0.077817  0.054736  0.000000  0.000000  0.000000  0.157778
#
# [10 rows x 1273 columns]

# %%
#User Based Collaborative Filter using Weighted Mean Ratings
def cf_user_wmean(user_id, item_id):
    
    #Check if item_id exists in r_matrix
    if item_id in r_matrix:
        
        #Get the similarity scores for the user in question with every other user
        sim_scores = cosine_sim[user_id]
        
        #Get the user ratings for the movie in question
        m_ratings = r_matrix[item_id]
        
        #Extract the indices containing NaN in the m_ratings series
        idx = m_ratings[m_ratings.isnull()].index
        
        #Drop the NaN values from the m_ratings Series
        m_ratings = m_ratings.dropna()
        
        #Drop the corresponding cosine scores from the sim_scores series
        sim_scores = sim_scores.drop(idx)
        
        #Compute the final weighted mean
        wmean_rating = np.dot(sim_scores, m_ratings)/ sim_scores.sum()
    
    else:
        #Default to a rating of 3.0 in the absence of any information
        wmean_rating = 3.0
    
    return wmean_rating

# %%
#compute the RMSE score for this model
score(cf_user_wmean)
# Out:
# 0.8127061141239906

# %%
#Import the required classes and methods from the surprise library
from surprise import Reader, Dataset, KNNBasic
from surprise.model_selection import cross_validate

#Define a Reader object
#The Reader object helps in parsing the file or dataframe containing ratings
reader = Reader()

#Create the dataset to be used for building the filter
data = Dataset.load_from_df(ratings, reader)

#Define the algorithm object; in this case kNN
knn = KNNBasic()

#Evaluate the performance in terms of RMSE
cross_validate(knn, data, measures=['RMSE'])
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# {'test_rmse': array([0.80998701, 0.81600321, 0.81435551, 0.80818309, 0.8174748 ]),
#  'fit_time': (0.14703989028930664,
#   0.13863635063171387,
#   0.14659333229064941,
#   0.1476151943206787,
#   0.14362168312072754),
#  'test_time': (0.8197588920593262,
#   0.815941572189331,
#   0.8018941879272461,
#   0.838726282119751,
#   0.790886402130127)}

# %%
#Import SVD
from surprise import SVD

#Define the SVD algorithm object
svd = SVD()

#Evaluate the performance in terms of RMSE
cross_validate(svd, data, measures=['RMSE'])
# Out:
# {'test_rmse': array([0.77884947, 0.76990988, 0.77292777, 0.77815603, 0.76076092]),
#  'fit_time': (1.8554131984710693,
#   1.8011794090270996,
#   1.8031480312347412,
#   1.8211328983306885,
#   1.7941982746124268),
#  'test_time': (0.058843374252319336,
#   0.05983996391296387,
#   0.05986785888671875,
#   0.06183743476867676,
#   0.058843374252319336)}

# %%
def healthiness_calculator(fat, saturatedFat, sugar):
    fatPoints = 0
    sugarPoints = 0
    satFatPoints = 0
    
    if fat < 30:
        fatPoints = 1
    if fat < 15:
        fatPoints = 2
    if fat < 3:
        fatPoints = 3  
        
    if saturatedFat < 10:
        satFatPoints = 1
    if saturatedFat < 5:
        satFatPoints = 2
    if saturatedFat < 1:
        satFatPoints = 3
        
    if sugar < 10:
        sugarPoints = 1
    if sugar < 5:
        sugarPoints = 2
    if sugar < 1:
        sugarPoints = 3
        
    return (fatPoints + sugarPoints + satFatPoints)

# %%
def add_meal_unhealtiness_rating(itemsDataframe):
    
    fat = ((itemsDataframe['Fat (g)'] * 9) / itemsDataframe['Calories (kCal)']) * 100
    sugar = ((itemsDataframe['Sugar (g)'] * 4) / itemsDataframe['Calories (kCal)']) * 100
    saturatedFat = ((itemsDataframe['Saturated Fat (g)'] * 9) / itemsDataframe['Calories (kCal)']) * 100
    
    itemsDataframe['Unhealtiness'] = fat + sugar + saturatedFat
    
        
    itemsDataframe['Healtiness'] = itemsDataframe.apply(healthiness_calculator(fat, saturatedFat, sugar))

# %%
add_meal_unhealtiness_rating(BMJ_data_all__b_new)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-1c92a9009223> in <module>
# ----> 1 add_meal_unhealtiness_rating(BMJ_data_all__b_new)
#
# <ipython-input-42-8ddff80f0d66> in add_meal_unhealtiness_rating(itemsDataframe)
#       8
#       9
# ---> 10     itemsDataframe['Healtiness'] = itemsDataframe.apply(healthiness_calculator(fat, saturatedFat, sugar))
#
# <ipython-input-41-9ee453e67867> in healthiness_calculator(fat, saturatedFat, sugar)
#       4     satFatPoints = 0
#       5
# ----> 6     if fat < 30:
#       7         fatPoints = 1
#       8     if fat < 15:
#
# C:\tools\miniconda3\envs\recommender\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
add_meal_unhealtiness_rating(item_profiles2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-a4f4a16e4bb4> in <module>
# ----> 1 add_meal_unhealtiness_rating(item_profiles2)
#
# <ipython-input-36-4dc893ed0dc8> in add_meal_unhealtiness_rating(itemsDataframe)
#      33
#      34
# ---> 35     itemsDataframe['Healtiness'] = itemsDataframe.apply(fatPoints + sugarPoints + satFatPoints)
#
# C:\tools\miniconda3\envs\recommender\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7546             kwds=kwds,
#    7547         )
# -> 7548         return op.get_result()
#    7549
#    7550     def applymap(self, func) -> "DataFrame":
#
# C:\tools\miniconda3\envs\recommender\lib\site-packages\pandas\core\apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# C:\tools\miniconda3\envs\recommender\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     269
#     270     def apply_standard(self):
# --> 271         results, res_index = self.apply_series_generator()
#     272
#     273         # wrap results
#
# C:\tools\miniconda3\envs\recommender\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     298                 for i, v in enumerate(series_gen):
#     299                     # ignore SettingWithCopy here in case the user mutates
# --> 300                     results[i] = self.f(v)
#     301                     if isinstance(results[i], ABCSeries):
#     302                         # If we have a view on v, we need to make a copy because
#
# TypeError: 'int' object is not callable

# %%
BMJ_data_all__b_new.head
# Out:
# <bound method NDFrame.head of                                                      URL  \
# 0      http://allrecipes.com/recipe/frosted-apricot-c...
# 1      http://allrecipes.com/recipe/italian-nachos-re...
# 2      http://allrecipes.com/recipe/brown-rice-and-ch...
# 3      http://allrecipes.com/recipe/erics-baked-chick...
# 4      http://allrecipes.com/recipe/olive-oil-pound-c...
# ...                                                  ...
# 58258  http://allrecipes.com/recipe/nikols-garlic-bru...
# 58259  http://allrecipes.com/recipe/slow-cooker-chick...
# 58260  http://allrecipes.com/recipe/bean-and-honey-bu...
# 58261  http://allrecipes.com/recipe/dill-dressing/det...
# 58262  http://allrecipes.com/recipe/chicken-and-artic...
#
#                                                  Name  Fiber (g)  Sodium (g)  \
# 0                             Frosted Apricot Cookies        0.7        0.20
# 1                     Italian Nachos Restaurant-Style        2.2        1.13
# 2                    Brown Rice and Chicken Casserole        2.4        0.71
# 3                                Eric's Baked Chicken        1.3        1.26
# 4                                Olive Oil Pound Cake        0.6        0.30
# ...                                               ...        ...         ...
# 58258                       Nikol's Garlic Bruschetta        0.9        0.17
# 58259                        Slow Cooker Chicken Stew        3.0        0.92
# 58260                Bean and Honey Burrito Casserole        4.9        0.60
# 58261                                   Dill Dressing        0.1        0.13
# 58262  Chicken And Artichoke Penne With A White Sauce        6.0        0.85
#
#        Carbohydrates (g)  Fat (g)  Protein (g)  Sugar (g)  Saturated Fat (g)  \
# 0                   24.6     11.2          2.2       11.1                7.3
# 1                   22.5     31.7         19.3        1.9               11.1
# 2                   19.1     10.0         17.5        3.1                4.6
# 3                   14.5     58.3         29.9        5.2               12.3
# 4                   44.0      3.7          4.5       26.1                0.9
# ...                  ...      ...          ...        ...                ...
# 58258               13.2      5.5          3.6        1.8                0.6
# 58259               28.6      7.6         47.2        4.7                2.1
# 58260               63.2     12.5         21.4       15.2                4.8
# 58261                0.4      1.8          0.1        0.1                0.1
# 58262               70.5     22.7         30.6        8.1                5.4
#
#        Size (g)  Servings  Calories (kCal)  Average Rating  Average Sentiment  \
# 0        610.20      12.0            203.0            3.00               1.50
# 1       1305.70       8.0            453.0            4.73               2.00
# 2       3099.18      12.0            238.0            3.29               0.00
# 3       2324.84       8.0            720.0            4.00               1.20
# 4       1112.48      12.0            227.0             NaN                NaN
# ...         ...       ...              ...             ...                ...
# 58258    856.15      12.0            113.0            5.00               2.00
# 58259   2596.18       6.0            378.0            4.29               1.59
# 58260   2424.90       8.0            446.0            4.44               1.88
# 58261    343.85      32.0             17.0             NaN                NaN
# 58262   1526.30       4.0            598.0            3.63               0.88
#
#        Number of Ratings  Number of Bookmarks  Year of Publishing  \
# 0                      2                   14                2004
# 1                     11                  195                2008
# 2                      7                  203                2005
# 3                      5                   89                2004
# 4                      0                    4                2005
# ...                  ...                  ...                 ...
# 58258                  7                  351                2009
# 58259                 17                  490                2001
# 58260                 16                  769                2009
# 58261                  0                   59                2010
# 58262                  8                  176                2001
#
#        Unhealtiness
# 0        103.891626
# 1         86.710817
# 2         60.420168
# 3         91.138889
# 4         64.229075
# ...             ...
# 58258     54.955752
# 58259     28.068783
# 58260     48.542601
# 58261    102.941176
# 58262     47.709030
#
# [58263 rows x 18 columns]>

# %%
item_profiles2.head
# Out:
# <bound method NDFrame.head of       Recipe ID                                      Name  Fiber (g)  \
# 0          2622  Slow Cooker Tender and Yummy Round Steak        4.5
# 1           722                        Chicken Pot Pie II        6.2
# 2          1137                          Chicken in a Pot        1.0
# 3          2502                 Erin's Indonesian Chicken        6.4
# 4          2714                              Bubble Pizza        3.0
# ...         ...                                       ...        ...
# 1026       1353                          Beef and Biscuit        0.9
# 1027        987                       Creamy Pesto Shrimp        2.7
# 1028       2903                            Boiled Chicken        1.2
# 1029       2136           Mushroom Sauce Baked Pork Chops        2.5
# 1030       3938                  Three Cheese Baked Pasta        5.2
#
#       Sodium (g)  Carbohydrates (g)  Fat (g)  Protein (g)  Sugar (g)  \
# 0           0.83               33.1     13.6         33.8        5.0
# 1           1.06               47.8     29.5         51.4        6.4
# 2           0.40                6.9      6.6         28.7        1.8
# 3           0.32               58.1     18.6         35.4        7.8
# 4           1.96               45.4     36.4         28.5        8.7
# ...          ...                ...      ...          ...        ...
# 1026        0.63               15.5     18.9         18.4        3.7
# 1027        0.44               43.0     42.5         23.1        0.2
# 1028        0.06                4.5     11.1         16.3        1.9
# 1029        1.11               28.1     14.3         19.0        6.5
# 1030        0.88               42.3     22.2         22.7       12.7
#
#       Saturated Fat (g)  Size (g)  Servings  Calories (kCal)  Average Rating  \
# 0                   4.6   2599.35       6.0            393.0            4.32
# 1                  11.4   2137.86       4.0            666.0            4.66
# 2                   1.4    819.37       4.0            206.0            4.29
# 3                   3.8   1972.13       4.0            530.0            4.39
# 4                  13.4   2375.00       8.0            624.0            4.35
# ...                 ...       ...       ...              ...             ...
# 1026                8.6   1536.45      10.0            306.0            3.99
# 1027               24.3   1655.88       8.0            646.0            4.58
# 1028                3.0   1780.00       8.0            186.0            4.70
# 1029                6.1   2241.75       6.0            316.0            4.45
# 1030               11.1   3368.20      12.0            463.0            4.57
#
#       Average Sentiment  Number of Ratings  Number of Bookmarks  \
# 0                  1.79                 81                 2271
# 1                  2.02                116                 1200
# 2                  1.98                 83                 1779
# 3                  1.99                 80                  872
# 4                  1.96                117                 2204
# ...                 ...                ...                  ...
# 1026               1.52                 79                  811
# 1027               1.98                225                 3134
# 1028               1.20                 74                 1083
# 1029               1.86                121                 1188
# 1030               1.76                 82                 1917
#
#       Year of Publishing  Unhealtiness
# 0                   2000     46.768448
# 1                   2000     59.114114
# 2                   2001     38.446602
# 3                   2005     43.924528
# 4                   2001     77.403846
# ...                  ...           ...
# 1026                2001     85.718954
# 1027                2000     93.188854
# 1028                2001     72.311828
# 1029                2001     66.329114
# 1030                2000     75.701944
#
# [1031 rows x 18 columns]>
